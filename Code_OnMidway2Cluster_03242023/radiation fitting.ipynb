# %%
from scipy.optimize import fsolve
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import CubicSpline

## read Turbet2021 data
# read data
coldtp = pd.read_csv('./screenshots/Turbet2021_data/Hot T-P.csv',header=None)
# assign headers
coldtp.columns = ["T", "P"]
# make data in right order (necessary for interpolation)
coldtp = coldtp.sort_values(by=['P'], ascending=True)
# interpolate data to a consistent pressure coordinate
T0 = coldtp['T']; P0 = coldtp['P'];
P = np.logspace(2, 6, 100)
cs = CubicSpline(P0, T0)
T_TB2021 = cs(P)

coldfp = pd.read_csv('./screenshots/Turbet2021_data/Hot f-P.csv',header=None)
# assign headers
coldfp.columns = ["f", "P"]
# make data in right order (necessary for interpolation)
coldfp = coldfp.sort_values(by=['P'], ascending=True)
# interpolate data to a consistent pressure coordinate
f0 = coldfp['f']; P0 = coldfp['P'];
P = np.logspace(2, 6, 100)
cs = CubicSpline(P0, f0)
f = cs(P)

coldabsp = pd.read_csv('./screenshots/Turbet2021_data/Hot abs-P.csv',header=None)
# assign headers
coldabsp.columns = ["dT", "P"]
# make data in right order (necessary for interpolation)
coldabsp = coldabsp.sort_values(by=['P'], ascending=True)
print(coldabsp)
# interpolate data to a consistent pressure coordinate
dT0 = coldabsp['dT']; P0 = coldabsp['P'];
P = np.logspace(2, 6, 100)
cs = CubicSpline(P0, dT0)
dT_TB2021 = cs(P)

# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(T_TB2021, P, linewidth = 2.0, label = 'interpolated')
ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Turbet2021 SW data")
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (Pa)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')

plt.show()
# Out:
#           dT             P
# 85  1.806220  1.421674e+01
# 84  1.627721  1.570770e+01
# 83  1.445043  1.786704e+01
# 82  1.282787  2.048042e+01
# 81  1.159888  2.359788e+01
# ..       ...           ...
# 4   0.000317  6.412675e+05
# 3   0.000252  7.239074e+05
# 2   0.000199  8.132337e+05
# 1   0.000157  9.129959e+05
# 0   0.000118  1.023106e+06
#
# [86 rows x 2 columns]

# %%
# read Turbet2023 data
# read data
coldtp = pd.read_csv('./screenshots/Turbet2023_data/T-P.csv',header=None)
# assign headers
coldtp.columns = ["T", "P"]
# make data in right order (necessary for interpolation)
coldtp = coldtp.sort_values(by=['P'], ascending=True)
# interpolate data to a consistent pressure coordinate
T0 = coldtp['T']; P0 = coldtp['P'];
P = np.logspace(2, 6, 100)
cs = CubicSpline(P0, T0)
T_TB2023 = cs(P)

coldabsp = pd.read_csv('./screenshots/Turbet2023_data/abs-P.csv',header=None)
# assign headers
coldabsp.columns = ["dT", "P"]
# make data in right order (necessary for interpolation)
coldabsp = coldabsp.sort_values(by=['P'], ascending=True)
print(coldabsp)
# interpolate data to a consistent pressure coordinate
dT0 = coldabsp['dT']; P0 = coldabsp['P'];
P = np.logspace(2, 6, 100)
cs = CubicSpline(P0, dT0)
dT_TB2023 = cs(P)

# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(dT_TB2023, P, linewidth = 2.0, label = 'interpolated')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Turbet2023 SW data")
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (Pa)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')
ax.set_xscale('log')

plt.show()
# Out:
#            dT             P
# 109  7.186473  1.389786e+01
# 108  6.155655  1.424344e+01
# 107  4.982313  1.552281e+01
# 106  4.200418  1.685781e+01
# 105  3.498307  1.841270e+01
# ..        ...           ...
# 4    0.000044  7.407654e+05
# 3    0.000036  8.081191e+05
# 2    0.000029  8.681133e+05
# 1    0.000023  9.896724e+05
# 0    0.000021  1.082588e+06
#
# [110 rows x 2 columns]

# %%
# read Selsis2023 data
# read data
coldtp = pd.read_csv('./screenshots/Selsis2023_data/T-P.csv',header=None)
# assign headers
coldtp.columns = ["T", "P"]
# make data in right order (necessary for interpolation)
coldtp = coldtp.sort_values(by=['P'], ascending=True)
# interpolate data to a consistent pressure coordinate
T0 = coldtp['T']; P0 = coldtp['P'];
P = np.logspace(2, 6, 100)
cs = CubicSpline(P0, T0)
T_SL2023 = cs(P)

coldabsp = pd.read_csv('./screenshots/Selsis2023_data/abs-P.csv',header=None)
# assign headers
coldabsp.columns = ["dT", "P"]
# make data in right order (necessary for interpolation)
coldabsp = coldabsp.sort_values(by=['P'], ascending=True)
print(coldabsp)
# interpolate data to a consistent pressure coordinate
dT0 = coldabsp['dT']; P0 = coldabsp['P'];
P = np.logspace(2, 6, 100)
cs = CubicSpline(P0, dT0)
dT_SL2023 = cs(P)

# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(dT_SL2023, P, linewidth = 2.0, label = 'interpolated')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Selsis2023 SW data")
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (Pa)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')
ax.set_xscale('log')

plt.show()
# Out:
#           dT             P
# 68  2.643265  2.254215e+01
# 69  2.553144  2.655419e+01
# 67  2.417675  3.186529e+01
# 65  2.303004  3.825857e+01
# 66  2.181569  4.521534e+01
# ..       ...           ...
# 4   0.000043  6.633911e+05
# 3   0.000033  7.410056e+05
# 2   0.000025  8.262167e+05
# 1   0.000019  9.300862e+05
# 0   0.000015  1.040769e+06
#
# [70 rows x 2 columns]

# %%
# Put the data from Turbet2021, Turbet2023, Selsis2023 together
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(T_TB2021, P, linewidth = 2.0, label = 'TB2021')
ax.plot(T_TB2023, P, linewidth = 2.0, label = 'TB2023')
ax.plot(T_SL2023, P, linewidth = 2.0, label = 'SL2023')
ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("P vs T from LMD papers")
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (Pa)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
plt.gca().invert_yaxis()
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')

plt.show()

# %%
import statistics
# Put the data from Turbet2021, Turbet2023, Selsis2023 together
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(dT_TB2021, P, linewidth = 2.0, label = 'TB2021')
ax.plot(dT_TB2023, P, linewidth = 2.0, label = 'TB2023')
ax.plot(dT_SL2023, P, linewidth = 2.0, label = 'SL2023')
ax.plot(0.2,900,'r+',label='CC')
ax.plot(0.5,900,'r+',label='CC')

ratio = (dT_TB2023/dT_TB2021)
print(ratio)
print(statistics.mean(ratio[P<900]))
# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("dT/dP vs P from LMD papers")
plt.xlabel("Heating Rate (W/kg)")
plt.ylabel("Pressure (Pa)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')
ax.set_xscale('log')
plt.gca().invert_yaxis()

plt.show()
# Out:
# [2.23662662 2.35132019 2.27334206 2.21321434 2.28300024 2.34184525
#  2.22093868 2.23301055 2.20841243 2.34490185 2.29047907 2.27870434
#  2.28071123 2.20881623 2.31215648 2.3657917  2.38064904 2.48650924
#  2.63007129 2.73174535 2.91222507 2.80251276 2.78055127 2.74979894
#  2.9566601  3.11438284 3.13534278 3.09698582 3.16242834 3.16836775
#  3.31473381 3.45450987 3.2185839  3.20439346 3.24208174 3.40420247
#  3.25937381 3.12125912 3.25082841 3.30940845 3.33020994 3.32944941
#  3.30612934 3.28289735 3.21257499 3.08914995 2.97396011 2.79986446
#  2.58813425 2.47057064 2.50716196 2.50611776 2.4883951  2.44041484
#  2.44460573 2.48833701 2.42790717 2.25730452 2.19296216 2.13850737
#  2.12864559 2.18930849 1.99880055 1.87326257 1.84709466 1.80535861
#  1.67543204 1.51677702 1.54016853 1.48728707 1.39202214 1.38692995
#  1.34193829 1.21867933 1.12604006 1.00399028 0.97602972 0.95017224
#  0.90031146 0.8971603  0.77115231 0.70637361 0.65291572 0.62451137
# ...

# %%
## Goal of this cell: calculate the integrated SW absorption coeffcient for G star 
# calculate the mass integrated heating rate
import scipy

# print(dT_TB2021[P<900])
dT_sub = dT_TB2021[P<900]
P_sub = P[P<900]

g_Earth = 9.8
S_Earth = 340.5
a_TB2021 = np.trapz(dT_sub*P_sub) / g_Earth / S_Earth
print(a_TB2021)
print(np.trapz(dT_sub*P_sub)/g_Earth)

# not effecttive
# dT_sub = dT_TB2023[T_TB2023<280]
# P_sub = P[T_TB2023<280]

# g_PC = 10.9
# S_PC = 956 / 2
# a_TB2023 = np.trapz(dT_sub*P_sub) / g_PC / S_PC
# print(a_TB2023)

# np.trapz(P_sub, x=P_sub)
# Out:
# 0.995099077375359
# 338.8312358463097

# %%
# Estimate SW absorption coeffcient from heating rate, didn't work
# Put the data from Turbet2021, Turbet2023, Selsis2023 together
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(T_TB2021, dT_TB2021, linewidth = 2.0, label = 'TB2021')
ax.plot(T_TB2023, dT_TB2023, linewidth = 2.0, label = 'TB2023')
ax.plot(T_SL2023, dT_SL2023, linewidth = 2.0, label = 'SL2023')
ax.plot(280,0.5,'r+',label='CC')
ax.plot(280,0.2,'r+',label='CC')
ax.plot(T_test, dF_test*13.7, linewidth = 2.0, label = 'SW - G')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("dT/dP vs T")
plt.ylabel("Heating Rate (W/kg)")
plt.xlabel("Temperature (K)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')
# plt.gca().invert_yaxis()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8dd9f736bbfd> in <module>
#       9 ax.plot(280,0.5,'r+',label='CC')
#      10 ax.plot(280,0.2,'r+',label='CC')
# ---> 11 ax.plot(T_test, dF_test*13.7, linewidth = 2.0, label = 'SW - G')
#      12
#      13 # ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#
# NameError: name 'T_test' is not defined

# %%
# A slightly more realistic scheme for SW absorption
RH = 1           # Dayside atmosphere relative humidity
es0 = 611.2         # reference pressure for CC relation
M = 0.018           # molar mass of water vapor
mm_dry = 0.028      # molar mass of dry air
mass_ratio = M/mm_dry    # mass ratio between vapor and dry air
L = 2.501e6                 # latent heat of vaporization in J/kg
To = 273.15                 # reference temperature for CC relation
R_star = 8.3145         # universal gas constant
Pc = 6e4
g = 13.7

T_test = np.linspace(220, 380, 100)
es = es0*pow(np.e, L/(R_star/M)*(1/To - 1/T_test))  # saturation vapor pressure
qs = mass_ratio*es/(Pc+mass_ratio*es) # saturated mixing ratio
q = RH * qs                 # vapor pressure 
# q = w / (1+w)               # specific humidity

kappa1 = 5e-3
k1 = kappa1*(Pc+es)/g

a1_test = 1 - np.exp(-k1*q)

kappa2 = 5e-3 * 2.5
# kappa2 = 5e-5
k2 = kappa2*(Pc+es)/g
a2_test = 1 - np.exp(-k2*q)

print(340.5/6e4*13.7)
# Put the data from Turbet2021, Turbet2023, Selsis2023 together
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(T_test, a1_test, linewidth = 2.0, label = 'Sun')
ax.plot(T_test, a2_test, linewidth = 2.0, label = 'Proxima')

print(a2_test/a1_test)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Atmos. Shortwave Absorption")
plt.ylabel("Absorption coeff.")
plt.xlabel("Temperature (K)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (10,8)
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')
# plt.gca().invert_yaxis()

plt.show()
# Out:
# 0.0777475
# [2.49776409 2.49732493 2.49680791 2.49620075 2.4954895  2.49465834
#  2.49368939 2.49256246 2.49125485 2.48974106 2.48799256 2.48597749
#  2.4836604  2.48100191 2.47795843 2.47448187 2.47051931 2.46601274
#  2.46089879 2.45510852 2.44856718 2.44119417 2.43290291 2.42360097
#  2.41319024 2.40156722 2.3886236  2.37424698 2.35832183 2.34073077
#  2.3213562  2.30008217 2.27679678 2.25139487 2.22378118 2.1938739
#  2.16160865 2.1269427  2.08985959 2.05037375 2.0085352  1.96443401
#  1.91820424 1.87002725 1.82013388 1.7688052  1.71637164 1.66321
#  1.60973822 1.55640772 1.50369338 1.45208117 1.40205404 1.35407645
#  1.30857842 1.26594011 1.22647779 1.1904324  1.15796149 1.12913524
#  1.10393679 1.08226693 1.06395266 1.04875882 1.03640198 1.02656542
#  1.01891453 1.01311149 1.00882881 1.00576089 1.0036332  1.00220858
#  1.00129036 1.00072239 1.0003863  1.00019667 1.000095   1.00004338
#  1.00001865 1.00000753 1.00000284 1.00000099 1.00000032 1.0000001
# ...

# %%
sigma = 5.67e-8
albedo = 0.3
S = 400
((1)*S/sigma)**(1/4) - ((1-albedo)*S/sigma)**(1/4)
# Out:
# 24.72367170764403

# %%
# Compare my SW scheme with Turbet2021
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(T_test, a1_test*340.5, linewidth = 2.0, label = 'SW absorption')
ax.plot(280,338.83, 'r+','TB2021')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("abs vs T")
plt.ylabel("SW absorption (W/m2)")
plt.xlabel("Temperature (K)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
ax.set_yscale('log')
# plt.gca().invert_yaxis()

plt.show()

# %%
# This cell tries to understand why heating rate can increase with pressure --> pressure-dependence of kappa
p = np.logspace(2, 5, 100)
k = 1e-10
kappa = 1e-4 * p ** 2
F0 = 500
tau = k * kappa * p
F = F0 * np.exp(-tau)
dF = -np.gradient(F, p)

# plot
fig, ax = plt.subplots()

ax.plot(p, dF, linewidth = 2.0, label = 'interpolated')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Hypothetical heating model")
plt.ylabel("Radiation flux (W/m2)")
plt.xlabel("Pressure (Pa)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
ax.set_xscale('log')
ax.set_yscale('log')

plt.show()

# %%
# Old SW scheme: CC relation
T_test = np.linspace(220, 280, 100)
a0 = 0.9
kappa = 1e4
T0 = 280
F0 = 340.5
dP = 6e4
dF_test = F0 * a0 * np.exp(-kappa*(1/T_test-1/T0)) / dP

# plot
fig, ax = plt.subplots()

ax.plot(T_test, dF_test, linewidth = 2.0, label = 'interpolated')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Current heating model")
plt.ylabel("Radiation flux (W/m2/Pa)")
plt.xlabel("Temperature (K)")
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (10,5)
ax.legend(loc='best', fontsize='x-small')

ax.set_yscale('log')

plt.show()

# %% [markdown]
# ## Starting from this cell, we calculate LW radiation instead of SW !!

# %%
temperate_LW = pd.read_csv('./screenshots/Yang2016_data/Yang2016_LW.csv',header=None)
# assign headers
temperate_LW.columns = ["Ts", "OLR"]
# make data in right order (necessary for interpolation)
temperate_LW = temperate_LW.sort_values(by=['Ts'], ascending=True)
print(temperate_LW)
# interpolate data to a consistent temperature coordinate
OLR0 = temperate_LW['OLR']; Ts0 = temperate_LW['Ts'];
Ts_Y2016 = np.linspace(250, 360, 50)
cs = CubicSpline(Ts0, OLR0)
OLR_Y2016 = cs(Ts_Y2016)

# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(Ts_Y2016, OLR_Y2016, linewidth = 2.0, label = 'interpolated')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Yang2016 LW data")
plt.xlabel("Surface Temperature (K)")
plt.ylabel("OLR (W/m2)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
# ax.set_yscale('log')

plt.show()
# Out:
#             Ts         OLR
# 0   252.240714  179.973133
# 1   256.064148  187.894547
# 2   259.696117  195.264651
# 3   263.574050  203.235161
# 4   267.151128  210.349183
# 5   271.261140  218.769834
# 6   274.986887  225.382232
# 7   279.189268  232.298774
# 8   282.054368  236.930493
# 9   287.173090  244.315105
# 10  292.103529  252.517398
# 11  295.532720  259.652922
# 12  299.322750  265.573574
# 13  303.635281  270.319510
# 14  307.831733  274.099903
# 15  312.028066  277.817574
# 16  316.224814  281.754774
# 17  320.421266  285.535168
# 18  324.616354  288.594247
# 19  328.811264  291.559241
# 20  333.006293  294.586959
# 21  337.201381  297.646038
# 22  341.394691  299.764272
# 23  345.584147  299.844010
# 24  349.774137  300.206001
# 25  352.250212  300.511138
# 26  357.222096  300.239595

# %%
runawayZ_LW = pd.read_csv('./screenshots/Chaverot2021_data/Zhang2020_LW.csv',header=None)
# assign headers
runawayZ_LW.columns = ["Ts", "OLR"]
# make data in right order (necessary for interpolation)
runawayZ_LW = runawayZ_LW.sort_values(by=['Ts'], ascending=True)
print(temperate_LW)
# interpolate data to a consistent temperature coordinate
OLR0 = runawayZ_LW['OLR']; Ts0 = runawayZ_LW['Ts'];
Ts_C2021 = np.linspace(250, 500, 200)
cs = CubicSpline(Ts0, OLR0)
OLR_Z2020 = cs(Ts_C2021)

# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(Ts_C2021, OLR_Z2020, linewidth = 2.0, label = 'interpolated')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Zhang2020 LW data")
plt.xlabel("Surface Temperature (K)")
plt.ylabel("OLR (W/m2)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
# ax.set_yscale('log')

plt.show()
# Out:
#             Ts         OLR
# 0   252.240714  179.973133
# 1   256.064148  187.894547
# 2   259.696117  195.264651
# 3   263.574050  203.235161
# 4   267.151128  210.349183
# 5   271.261140  218.769834
# 6   274.986887  225.382232
# 7   279.189268  232.298774
# 8   282.054368  236.930493
# 9   287.173090  244.315105
# 10  292.103529  252.517398
# 11  295.532720  259.652922
# 12  299.322750  265.573574
# 13  303.635281  270.319510
# 14  307.831733  274.099903
# 15  312.028066  277.817574
# 16  316.224814  281.754774
# 17  320.421266  285.535168
# 18  324.616354  288.594247
# 19  328.811264  291.559241
# 20  333.006293  294.586959
# 21  337.201381  297.646038
# 22  341.394691  299.764272
# 23  345.584147  299.844010
# 24  349.774137  300.206001
# 25  352.250212  300.511138
# 26  357.222096  300.239595

# %%
from scipy import interpolate

runawayS_M = pd.read_csv('./screenshots/Selsis2023_data/T-OLR_M.csv',header=None)
# assign headers
runawayS_M.columns = ["Ts", "OLR"]
# make data in right order (necessary for interpolation)
runawayS_M = runawayS_M.sort_values(by=['Ts'], ascending=True)
# print(temperate_LW)
# interpolate data to a consistent temperature coordinate
OLR0 = runawayS_M['OLR']; Ts0 = runawayS_M['Ts'];

f = interpolate.interp1d(Ts0, OLR0, fill_value='extrapolate')
Ts_S2023_M = np.linspace(600, 2700, 1000)
OLR_S2023_M = f(Ts_S2023_M)

runawayS_G = pd.read_csv('./screenshots/Selsis2023_data/T-OLR_G.csv',header=None)
# assign headers
runawayS_G.columns = ["Ts", "OLR"]
# make data in right order (necessary for interpolation)
runawayS_G = runawayS_G.sort_values(by=['Ts'], ascending=True)
# print(temperate_LW)
# interpolate data to a consistent temperature coordinate
OLR0 = runawayS_G['OLR']; Ts0 = runawayS_G['Ts'];

f = interpolate.interp1d(Ts0, OLR0, fill_value='extrapolate')
Ts_S2023_G = np.linspace(600, 2700, 1000)
OLR_S2023_G = f(Ts_S2023_G)


# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(Ts_S2023_M, OLR_S2023_M, linewidth = 2.0, label = 'M star')
ax.plot(Ts_S2023_G, OLR_S2023_G, linewidth = 2.0, label = 'G star')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Selsis2023 LW data")
plt.xlabel("Surface Temperature (K)")
plt.ylabel("OLR (W/m2)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
# ax.set_yscale('log')

plt.show()

# %%
runawayC_LW = pd.read_csv('./screenshots/Chaverot2021_data/Chaverot2021_LW.csv',header=None)
# assign headers
runawayC_LW.columns = ["Ts", "OLR"]
# make data in right order (necessary for interpolation)
runawayC_LW = runawayC_LW.sort_values(by=['Ts'], ascending=True)
# print(temperate_LW)
# interpolate data to a consistent temperature coordinate
OLR0 = runawayC_LW['OLR']; Ts0 = runawayC_LW['Ts'];
Ts_C2021 = np.linspace(250, 500, 200)
cs = CubicSpline(Ts0, OLR0)
OLR_C2021 = cs(Ts_C2021)

# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(Ts_C2021, OLR_C2021, linewidth = 2.0, label = 'interpolated')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Chaverot2021 LW data")
plt.xlabel("Surface Temperature (K)")
plt.ylabel("OLR (W/m2)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
# ax.set_yscale('log')

plt.show()

# %%
# A slightly more realistic scheme for LW absorption
RH = 1           # Dayside atmosphere relative humidity
es0 = 611.2         # reference pressure for CC relation
M = 0.018           # molar mass of water vapor
mm_dry = 0.028      # molar mass of dry air
mass_ratio = M/mm_dry    # mass ratio between vapor and dry air
L = 2.501e6                 # latent heat of vaporization in J/kg
To = 273.15                 # reference temperature for CC relation
R_star = 8.3145         # universal gas constant
Pc = 6e4
g = 13.7
sigma = 5.67e-8

T_test = np.linspace(220, 500, 300)
es = es0*pow(np.e, L/(R_star/M)*(1/To - 1/T_test))  # saturation vapor pressure
qs = mass_ratio*es/(Pc+mass_ratio*es) # saturated mixing ratio
q = RH * qs                 # vapor pressure 
# q = w / (1+w)               # specific humidity

# kappa1 = 5e-3
# k1 = kappa1*(Pc+es)/g
k1 = 5000
e1_test = 1 - np.exp(-k1*q)

kappa1 = k1 * g / Pc
kappa2 = kappa1
k2 = kappa2*(Pc+es)/g
e2_test = 1 - np.exp(-k2*q)

OLR1 = e2_test*sigma*T_test**4

trans_data = pd.read_csv('./screenshots/Chaverot2021_data/Ts-Trans.csv',header=None)
# assign headers
trans_data.columns = ["Ts", "Trans"]
# make data in right order (necessary for interpolation)
trans_data = trans_data.sort_values(by=['Ts'], ascending=True)
# print(temperate_LW)
# interpolate data to a consistent temperature coordinate
Trans0 = trans_data['Trans']; Ts0 = trans_data['Ts'];
# T_test = np.linspace(220, 380, 100)
Trans_K2018 = np.interp(T_test,Ts0, Trans0)
# cs = CubicSpline(Ts0, Trans0)
# Trans_K2018 = cs(T_test)
# Trans_K2018[Trans_K2018 < 0.01] = 0
# print(Trans_K2018)

T1 = 270
OLR2 = Trans_K2018 * e2_test*sigma*T_test**4 + (1-Trans_K2018) * sigma * T1 ** 4

# Put the data from Turbet2021, Turbet2023, Selsis2023 together
fig, ax = plt.subplots()

ax.plot(T_test, OLR1, linewidth=2.0,label = 'original')
ax.plot(T_test, OLR2, linewidth=2.0,label = 'modified')
# ax.plot(T_test, Trans_K2018, linewidth=2.0,label = 'original')
plt.title(r"OLR vs T")
plt.ylabel("LW Emission (W/m2)")

# ax.plot(T_test, a1_test, linewidth = 2.0, label = 'Yang2014')
# ax.plot(T_test, a2_test, linewidth = 2.0, label = 'Preesure effect')
# plt.title(r"$\epsilon$ vs T")
# plt.ylabel("Emission coefficient")

# print(a2_test/a1_test)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.xlabel("Temperature (K)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
# ax.set_yscale('log')
# plt.gca().invert_yaxis()

plt.show()

# %%
# Put the data from Yang2016, Zhang2020, Chaverot2021 together
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(Ts_Y2016, OLR_Y2016, linewidth = 2.0, label = 'Yang2016')
ax.plot(Ts_C2021, OLR_Z2020, linewidth = 2.0, label = 'Zhang2020')
ax.plot(Ts_C2021, OLR_C2021, linewidth = 2.0, label = 'Chaverot2021')
ax.plot(T_test, OLR1, linewidth=2.0,label = 'Updated LW scheme')
ax.plot(T_test, OLR2, linewidth=2.0,label = 'original LW scheme')
ax.plot(400, 5.67e-8*270**4,'r+',label = 'approximation')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("OLR vs Ts")
plt.xlabel("Surface Temperature (K)")
plt.ylabel("OLR (W/m2)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (10,8)
# plt.gca().invert_yaxis()
ax.legend(loc='best', fontsize='xx-small')
plt.ylim(150, 350)
# ax.set_yscale('log')

plt.show()

# %%
# A even more realistic scheme for LW absorption
RH = 1           # Dayside atmosphere relative humidity
es0 = 611.2         # reference pressure for CC relation
M = 0.018           # molar mass of water vapor
mm_dry = 0.028      # molar mass of dry air
mass_ratio = M/mm_dry    # mass ratio between vapor and dry air
L = 2.501e6                 # latent heat of vaporization in J/kg
To = 273.15                 # reference temperature for CC relation
R_star = 8.3145         # universal gas constant
Pc = 6e4
g = 13.7
sigma = 5.67e-8

T_test = np.linspace(200, 1500, 900)
es = es0*pow(np.e, L/(R_star/M)*(1/To - 1/T_test))  # saturation vapor pressure
qs = mass_ratio*es/(Pc+mass_ratio*es) # saturated mixing ratio
q = RH * qs                 # vapor pressure 
# q = w / (1+w)               # specific humidity

# kappa1 = 5e-3
# k1 = kappa1*(Pc+es)/g
k1 = 5000
e1_test = 1 - np.exp(-k1*q)

kappa1 = k1 * g / Pc
kappa2 = kappa1
k2 = kappa2*(Pc+es)/g
e2_test = 1 - np.exp(-k2*q)

OLR1 = e2_test*sigma*T_test**4

trans_data = pd.read_csv('./screenshots/Chaverot2021_data/Ts-Trans.csv',header=None)
# assign headers
trans_data.columns = ["Ts", "Trans"]
# make data in right order (necessary for interpolation)
trans_data = trans_data.sort_values(by=['Ts'], ascending=True)
# print(temperate_LW)
# interpolate data to a consistent temperature coordinate
Trans0 = trans_data['Trans']; Ts0 = trans_data['Ts'];
# T_test = np.linspace(220, 380, 100)
Trans_K2018 = np.interp(T_test, Ts0, Trans0)
# cs = CubicSpline(Ts0, Trans0)
# Trans_K2018 = cs(T_test)
# Trans_K2018[Trans_K2018 < 0.01] = 0
# print(Trans_K2018)

T1 = 270
OLR2 = Trans_K2018 * e2_test*sigma*T_test**4 + (1-Trans_K2018) * sigma * T1 ** 4

OLR3 = OLR2 - 1e-9
OLR3[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T1**4

Trans_0p1 = np.interp(T_test, Ts0-15, Trans0)
OLR4 = Trans_0p1 * e2_test*sigma*T_test**4 + (1-Trans_0p1) * sigma * T1 ** 4
OLR4[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T1**4

Trans_0 = np.interp(T_test, Ts0-30, Trans0)
OLR5 = Trans_0 * e2_test*sigma*T_test**4 + (1-Trans_0) * sigma * T1 ** 4
OLR5[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T1**4

OLR6 = np.zeros_like(T_test, dtype=float)
T_ref = 270
# Find the index of the value in T_test closest to T_ref
index_T_ref = (np.abs(T_test - T_ref)).argmin()
OLR_ref = OLR5[index_T_ref]
# Create OLR6 based on conditions
slope = 3
for i, T in enumerate(T_test):
    if T < T_ref:
        OLR6[i] = OLR_ref - slope * (T_ref - T)
    elif T == T_ref:
        OLR6[i] = OLR_ref
    elif T > 850:
        OLR6[i] = OLR_ref + slope * (T - 850)
    else:
        OLR6[i] = OLR_ref


# Official plot for the radiation scheme
fig, ax = plt.subplots(figsize=(12,8))
# ax.plot(T_test,np.gradient(OLR6),'--k')

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(T_test, OLR5, '-b',linewidth=3.0,label = 'This work (default, pN2 = 0 bar)')
ax.plot(T_test, OLR6, '--b',linewidth=3.0,label = 'Linearized OLR')
# ax.plot(T_test, OLR7, '--r',linewidth=3.0,label = 'Test2')
ax.plot(T_test, OLR1, linewidth=2.0,label = 'Yang+2014')
# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))
ax.set_title("Outgoing Longwave Radiation")
ax.set_xlabel("Temperature (K)")
ax.set_ylabel(r"$W/m^2$")
# plt.gca().invert_yaxis()
ax.legend(loc='upper left', fontsize='x-small')
ax.set_ylim(50, 1800)
ax.set_xlim(200, 1500)
# ax.set_xscale('log')
ax.set_xticks([200,300,400,600,1000,1500]) 
ax.set_xticklabels([200,300,400,600, 1000, 1500]) 
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (30,8)

plt.show()

# %%
# # Official plot for the radiation scheme
# fig, ax = plt.subplots(figsize=(12,8))

plt.figure(figsize=(12, 8))

# plt.subplot(2, 3, 1) 
# ax.plot(T0, P0, linewidth=2.0,label = 'original')
plt.plot(T_test, OLR5, '-b',linewidth=3.0,label = 'This work (default)')
plt.plot(T_test, OLR6, '--r',linewidth=3.0,label = 'This work (linearized)')
# plt.plot(T_test, OLR3, '--r',linewidth=2.0,label = 'This work (pN2 = 1 bar)')
# ax.plot(T_test[T_test<280], OLR1[T_test<280], linewidth=2.0,label = 'Yang+2014')
plt.plot(T_test, OLR1, '-c',linewidth=2.0,label = 'Yang+2014')
plt.plot(Ts_Y2016, OLR_Y2016, '-',linewidth = 2.0, label = 'Yang+2016')
plt.plot(Ts_C2021, OLR_Z2020, linewidth = 2.0, label = 'Zhang+2020')
plt.plot(Ts_C2021, OLR_C2021, linewidth = 2.0, label = 'Chaverot+2021')
plt.plot(Ts_S2023_M, OLR_S2023_M, linewidth = 2.0, label = 'Selsis+2023 (Proxima)')
plt.plot(Ts_S2023_G, OLR_S2023_G, linewidth = 2.0, label = 'Selsis+2023 (Sun)')
plt.plot([800, 900], [320, 320],'b*',label = 'Chaverot+2023')
plt.plot([1000, 1050], [400, 560],'r*',label = 'Turbet+2021')
# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
plt.title("OLR (compare with others)")
plt.xlabel("Temperature (K)")
plt.ylabel(r"$W/m^2$")
# plt.gca().invert_yaxis()
plt.legend(loc='upper left', fontsize='x-small')
plt.ylim(150, 600)
plt.xlim(200, 1500)
plt.xticks([200,400,600,1000,1500]) 
# plt.rcParams.update({'font.size': 20})
# plt.rcParams["figure.figsize"] = (30,8)


plt.show()

# %%
# A even more realistic scheme for LW absorption
RH = 1           # Dayside atmosphere relative humidity
es0 = 611.2         # reference pressure for CC relation
M = 0.018           # molar mass of water vapor
mm_dry = 0.028      # molar mass of dry air
mass_ratio = M/mm_dry    # mass ratio between vapor and dry air
L = 2.501e6                 # latent heat of vaporization in J/kg
To = 273.15                 # reference temperature for CC relation
R_star = 8.3145         # universal gas constant
Pc = 6e4
g = 13.7
sigma = 5.67e-8

T_test = np.linspace(220, 1500, 900)
es = es0*pow(np.e, L/(R_star/M)*(1/To - 1/T_test))  # saturation vapor pressure
qs = mass_ratio*es/(Pc+mass_ratio*es) # saturated mixing ratio
q = RH * qs                 # vapor pressure 
# q = w / (1+w)               # specific humidity

# kappa1 = 5e-3
# k1 = kappa1*(Pc+es)/g
k1 = 5000
e1_test = 1 - np.exp(-k1*q)

kappa1 = k1 * g / Pc
kappa2 = kappa1
k2 = kappa2*(Pc+es)/g
e2_test = 1 - np.exp(-k2*q)

OLR1 = e2_test*sigma*T_test**4

trans_data = pd.read_csv('./screenshots/Chaverot2021_data/Ts-Trans.csv',header=None)
# assign headers
trans_data.columns = ["Ts", "Trans"]
# make data in right order (necessary for interpolation)
trans_data = trans_data.sort_values(by=['Ts'], ascending=True)
# print(temperate_LW)
# interpolate data to a consistent temperature coordinate
Trans0 = trans_data['Trans']; Ts0 = trans_data['Ts'];
# T_test = np.linspace(220, 380, 100)
Trans_K2018 = np.interp(T_test, Ts0, Trans0)
# cs = CubicSpline(Ts0, Trans0)
# Trans_K2018 = cs(T_test)
# Trans_K2018[Trans_K2018 < 0.01] = 0
# print(Trans_K2018)

T1 = 270
OLR2 = Trans_K2018 * e2_test*sigma*T_test**4 + (1-Trans_K2018) * sigma * T1 ** 4

OLR3 = OLR2 - 1e-9
OLR3[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T1**4

Trans_0p1 = np.interp(T_test, Ts0-15, Trans0)
OLR4 = Trans_0p1 * e2_test*sigma*T_test**4 + (1-Trans_0p1) * sigma * T1 ** 4
OLR4[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T1**4

Trans_0 = np.interp(T_test, Ts0-30, Trans0)
OLR5 = Trans_0 * e2_test*sigma*T_test**4 + (1-Trans_0) * sigma * T1 ** 4
OLR5[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T1**4

T_off = 400
OLR61 = Trans_0 * e2_test*sigma*T_test**4 + (1 - Trans_0) * sigma * T1 ** 4
OLR61[T_test>T_off] = OLR61[T_test>T_off] + (1-Trans_0[T_test>T_off]) * 5.67e-3*(T_test[T_test>T_off]-T_off)**2

T_off = 270
OLR62 = Trans_0 * e2_test*sigma*T_test**4 + (1 - Trans_0) * sigma * T1 ** 4
OLR62[T_test>T_off] = OLR62[T_test>T_off] + (1-Trans_0[T_test>T_off]) * 5.67e-3*(T_test[T_test>T_off]-T_off)**2

T_onset = 250
Trans_0 = np.interp(T_test, Ts0-30, Trans0)
OLR71 = Trans_0 * e2_test*sigma*T_test**4 + (1-Trans_0) * sigma * T_onset ** 4
OLR71[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T_onset**4

T_onset = 300
Trans_0 = np.interp(T_test, Ts0-30, Trans0)
OLR72 = Trans_0 * e2_test*sigma*T_test**4 + (1-Trans_0) * sigma * T_onset ** 4
OLR72[T_test>850] = 5.67e-3*(T_test[T_test>850]-850)**2 + sigma*T_onset**4


T_sup = 270
k_sup = 0.006
# Initialize OLR7 as a copy of OLR1
OLR8 = np.array(OLR1, copy=True)
# Indices where T_test is greater than T_sup
indices = np.where(T_test > T_sup)
# Adjust OLR7 values for T_test > T_sup
# OLR7 increases slower by a factor of k_sup compared to the increase in OLR1
# Calculate the base increase from the point T_sup is crossed
base_increase = OLR1[indices] - OLR1[indices[0][0] - 1]  # Difference from the first value exceeding T_sup
# Apply the slower increase factor k_sup
slower_increase = base_increase * k_sup
# Update OLR7 starting from the first index where T_test > T_sup
OLR8[indices] = OLR1[indices[0][0] - 1] + slower_increase

k_sup = 0.001
# Initialize OLR7 as a copy of OLR1
OLR81 = np.array(OLR1, copy=True)
# Indices where T_test is greater than T_sup
indices = np.where(T_test > T_sup)
# Adjust OLR7 values for T_test > T_sup
# OLR7 increases slower by a factor of k_sup compared to the increase in OLR1
# Calculate the base increase from the point T_sup is crossed
base_increase = OLR1[indices] - OLR1[indices[0][0] - 1]  # Difference from the first value exceeding T_sup
# Apply the slower increase factor k_sup
slower_increase = base_increase * k_sup
# Update OLR7 starting from the first index where T_test > T_sup
OLR81[indices] = OLR1[indices[0][0] - 1] + slower_increase

k_sup = 0.02
# Initialize OLR7 as a copy of OLR1
OLR82 = np.array(OLR1, copy=True)
# Indices where T_test is greater than T_sup
indices = np.where(T_test > T_sup)
# Adjust OLR7 values for T_test > T_sup
# OLR7 increases slower by a factor of k_sup compared to the increase in OLR1
# Calculate the base increase from the point T_sup is crossed
base_increase = OLR1[indices] - OLR1[indices[0][0] - 1]  # Difference from the first value exceeding T_sup
# Apply the slower increase factor k_sup
slower_increase = base_increase * k_sup
# Update OLR7 starting from the first index where T_test > T_sup
OLR82[indices] = OLR1[indices[0][0] - 1] + slower_increase

T_sup = 250
# Initialize OLR7 as a copy of OLR1
OLR83 = np.array(OLR1, copy=True)
# Indices where T_test is greater than T_sup
indices = np.where(T_test > T_sup)
# Adjust OLR7 values for T_test > T_sup
# OLR7 increases slower by a factor of k_sup compared to the increase in OLR1
# Calculate the base increase from the point T_sup is crossed
base_increase = OLR1[indices] - OLR1[indices[0][0] - 1]  # Difference from the first value exceeding T_sup
# Apply the slower increase factor k_sup
slower_increase = base_increase * k_sup
# Update OLR7 starting from the first index where T_test > T_sup
OLR83[indices] = OLR1[indices[0][0] - 1] + slower_increase

T_sup = 300
# Initialize OLR7 as a copy of OLR1
OLR84 = np.array(OLR1, copy=True)
# Indices where T_test is greater than T_sup
indices = np.where(T_test > T_sup)
# Adjust OLR7 values for T_test > T_sup
# OLR7 increases slower by a factor of k_sup compared to the increase in OLR1
# Calculate the base increase from the point T_sup is crossed
base_increase = OLR1[indices] - OLR1[indices[0][0] - 1]  # Difference from the first value exceeding T_sup
# Apply the slower increase factor k_sup
slower_increase = base_increase * k_sup
# Update OLR7 starting from the first index where T_test > T_sup
OLR84[indices] = OLR1[indices[0][0] - 1] + slower_increase

# Official plot for the radiation scheme
fig, ax = plt.subplots(figsize=(12,8))
# ax.plot(T_test,np.gradient(OLR6),'--k')

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(T_test, OLR5, '-b',linewidth=3.0,label = 'This work (default, pN2 = 0 bar)')
# ax.plot(T_test, OLR6, '--b',linewidth=3.0,label = 'Test')
ax.plot(T_test, OLR7, '--r',linewidth=3.0,label = 'Test2')
ax.plot(T_test, OLR1, linewidth=2.0,label = 'Yang+2014')
# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))
ax.set_title("Outgoing Longwave Radiation")
ax.set_xlabel("Temperature (K)")
ax.set_ylabel(r"$W/m^2$")
# plt.gca().invert_yaxis()
ax.legend(loc='upper left', fontsize='x-small')
ax.set_ylim(150, 1800)
ax.set_xlim(200, 1500)
ax.set_xscale('log')
ax.set_xticks([200,300,400,600,1000,1500]) 
ax.set_xticklabels([200,300,400,600, 1000, 1500]) 
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (30,8)

plt.show()

# # Put the data from Turbet2021, Turbet2023, Selsis2023 together
# fig, ax = plt.subplots()

# # ax.plot(T_test, OLR1, linewidth=2.0,label = 'original')
# # ax.plot(T_test, OLR2, linewidth=2.0,label = 'modified')
# # ax.plot(T_test, OLR3, linewidth=2.0,label = 'even modified')
# # ax.plot(T_test, OLR4, linewidth=2.0,label = r'$p_{N2}$ = 0.1 bar')
# # ax.plot(T_test, OLR5, linewidth=2.0,label = r'$p_{N2}$ = 0 bar')
# ax.plot(T_test, Trans_0, linewidth=2.0,label = 'original')
# plt.title(r"OLR vs T")
# plt.ylabel("LW Emission (W/m2)")

# # ax.plot(T_test, a1_test, linewidth = 2.0, label = 'Yang2014')
# # ax.plot(T_test, a2_test, linewidth = 2.0, label = 'Preesure effect')
# # plt.title(r"$\epsilon$ vs T")
# # plt.ylabel("Emission coefficient")

# # print(a2_test/a1_test)

# # ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
# #        ylim=(0, 8), yticks=np.arange(1, 8))

# plt.xlabel("Temperature (K)")
# plt.rcParams.update({'font.size': 30})
# plt.rcParams["figure.figsize"] = (20,10)
# ax.legend(loc='best', fontsize='x-small')
# # plt.ylim(200, 350)
# plt.xlim(250, 400)
# # ax.set_yscale('log')
# # plt.gca().invert_yaxis()

# plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(T_test[T_test<400], es[T_test<400], linewidth=2.0,label = 'original')
# ax.plot(T_test, OLR2, linewidth=2.0,label = 'modified')
# ax.plot(T_test, OLR3, linewidth=2.0,label = 'even modified')
# ax.plot(T_test, Trans_K2018, linewidth=2.0,label = 'original')
plt.title(r"e vs T")
plt.ylabel("vapor pressure (Pa)")

# ax.plot(T_test, a1_test, linewidth = 2.0, label = 'Yang2014')
# ax.plot(T_test, a2_test, linewidth = 2.0, label = 'Preesure effect')
# plt.title(r"$\epsilon$ vs T")
# plt.ylabel("Emission coefficient")

# print(a2_test/a1_test)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.xlabel("Temperature (K)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
plt.xlim(250, 400)
ax.set_yscale('log')
# plt.gca().invert_yaxis()

plt.show()

# %%
# Put the data from Yang2016, Zhang2020, Chaverot2021 together
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
ax.plot(Ts_Y2016, OLR_Y2016, linewidth = 2.0, label = 'Yang2016')
ax.plot(Ts_C2021, OLR_Z2020, linewidth = 2.0, label = 'Zhang2020')
ax.plot(Ts_C2021, OLR_C2021, linewidth = 2.0, label = 'Chaverot2021')
ax.plot(Ts_S2023_M, OLR_S2023_M, linewidth = 2.0, label = 'Selsis2023 M')
ax.plot(Ts_S2023_G, OLR_S2023_G, linewidth = 2.0, label = 'Selsis2023 G')
ax.plot(T_test[T_test<300], OLR1[T_test<300], linewidth=2.0,label = 'original LW scheme')
ax.plot(T_test, OLR2, linewidth=2.0,label = 'updated LW scheme')
ax.plot(T_test, OLR3, linewidth=2.0,label = 'runaway LW scheme')
ax.plot([800, 900], [320, 320],'b+',label = 'C2023')
ax.plot([1000, 1050], [400, 560],'b*',label = 'T2023')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("OLR vs Ts")
plt.xlabel("Surface Temperature (K)")
plt.ylabel("OLR (W/m2)")
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (30,8)
# plt.gca().invert_yaxis()
ax.legend(loc='best', fontsize='x-small')
plt.ylim(150, 2300)
# ax.set_yscale('log')

plt.show()

# %%
# # Official plot for the radiation scheme
# fig, ax = plt.subplots(figsize=(12,8))

plt.figure(figsize=(12, 8))

# plt.subplot(2, 3, 1) 
# ax.plot(T0, P0, linewidth=2.0,label = 'original')
plt.plot(T_test, OLR5, '-b',linewidth=3.0,label = 'This work (default, pN2 = 0 bar)')
plt.plot(T_test, OLR3, '--r',linewidth=3.0,label = 'This work (pN2 = 1 bar)')
# ax.plot(T_test[T_test<280], OLR1[T_test<280], linewidth=2.0,label = 'Yang+2014')
plt.plot(T_test, OLR1, '-c',linewidth=2.0,label = 'Yang+2014')
plt.plot(Ts_Y2016, OLR_Y2016, '-',linewidth = 2.0, label = 'Yang+2016')
plt.plot(Ts_C2021, OLR_Z2020, linewidth = 2.0, label = 'Zhang+2020')
plt.plot(Ts_C2021, OLR_C2021, linewidth = 2.0, label = 'Chaverot+2021')
plt.plot(Ts_S2023_M, OLR_S2023_M, linewidth = 2.0, label = 'Selsis+2023 (Proxima)')
plt.plot(Ts_S2023_G, OLR_S2023_G, linewidth = 2.0, label = 'Selsis+2023 (Sun)')
plt.plot([800, 900], [320, 320],'b*',label = 'Chaverot+2023')
plt.plot([1000, 1050], [400, 560],'r*',label = 'Turbet+2021')
# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
plt.title("OLR (compare with others)")
plt.xlabel("Temperature (K)")
plt.ylabel(r"$W/m^2$")
# plt.gca().invert_yaxis()
plt.legend(loc='upper left', fontsize='x-small')
plt.ylim(150, 600)
plt.xlim(200, 1500)
plt.xticks([200,400,600,1000,1500]) 
# plt.rcParams.update({'font.size': 20})
# plt.rcParams["figure.figsize"] = (30,8)

# plt.subplot(2, 3, 2) 
# # ax.plot(T0, P0, linewidth=2.0,label = 'original')
# plt.plot(T_test, OLR5, '-b',linewidth=3.0,label = r'Default ($T_{end}$ = 850 K)')
# plt.plot(T_test, OLR61, '-k',linewidth=3.0,label = r'$T_{end}$ = 400 K')
# plt.plot(T_test, OLR62, '--k',linewidth=3.0,label = r'$T_{end}$ = 270 K')
# # ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
# plt.title(r"OLR (changing $T_{end}$)")
# plt.xlabel("Temperature (K)")
# # plt.ylabel(r"$W/m^2$")
# # plt.gca().invert_yaxis()
# plt.legend(loc='upper left', fontsize='x-small')
# plt.ylim(150, 600)
# plt.xlim(200, 1000)
# plt.xticks([200,400,600,1000]) 

# plt.subplot(2, 3, 3) 
# # ax.plot(T0, P0, linewidth=2.0,label = 'original')
# plt.plot(T_test, OLR5, '-b',linewidth=3.0,label = r'Default ($T_{e,\;run}$ = 270 K)')
# plt.plot(T_test, OLR71, '-k',linewidth=3.0,label = r'$T_{e,\;run}$ = 250 K')
# plt.plot(T_test, OLR72, '--k',linewidth=3.0,label = r'$T_{e,\;run}$ = 300 K')
# # ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
# plt.title(r"OLR (changing $T_{e,\;run}$)")
# plt.xlabel("Temperature (K)")
# # plt.ylabel(r"$W/m^2$")
# # plt.gca().invert_yaxis()
# plt.legend(loc='upper left', fontsize='x-small')
# plt.ylim(150, 600)
# plt.xlim(200, 1000)
# plt.xticks([200,400,600,1000]) 

# plt.subplot(2, 3, 4) 
# # ax.plot(T0, P0, linewidth=2.0,label = 'original')
# plt.plot(T_test, OLR5, '-b',linewidth=3.0,label = r'Default')
# plt.plot(T_test, OLR1, '-c',linewidth=2.0,label = 'Yang+2014')
# plt.plot(T_test, OLR8, '--c',linewidth=3.0,label = r'idelized OLR ($T_{ideal}$ = 270 K, $k_{ideal}$ = 0.006)')
# # plt.plot(T_test, OLR62, '--k',linewidth=3.0,label = r'$T_{end}$ = 270 K')
# # ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
# plt.title(r"OLR (idealized version)")
# plt.xlabel("Temperature (K)")
# plt.ylabel(r"$W/m^2$")
# # plt.gca().invert_yaxis()
# plt.legend(loc='upper left', fontsize='x-small')
# plt.ylim(150, 600)
# plt.xlim(200, 1000)
# plt.xticks([200,400,600,1000]) 

# plt.subplot(2, 3, 5) 
# # ax.plot(T0, P0, linewidth=2.0,label = 'original')
# plt.plot(T_test, OLR8, '-c',linewidth=3.0,label = r'$k_{ideal}$ = 0.006')
# plt.plot(T_test, OLR81, '-k',linewidth=2.0,label = '$k_{ideal}$ = 0.001')
# plt.plot(T_test, OLR82, '--k',linewidth=3.0,label = r'$k_{ideal}$ = 0.02')
# # plt.plot(T_test, OLR62, '--k',linewidth=3.0,label = r'$T_{end}$ = 270 K')
# # ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
# plt.title(r"idealized OLR (changing $k_{ideal}$)")
# plt.xlabel("Temperature (K)")
# # plt.ylabel(r"$W/m^2$")
# # plt.gca().invert_yaxis()
# plt.legend(loc='upper left', fontsize='x-small')
# plt.ylim(150, 600)
# plt.xlim(200, 1000)
# plt.xticks([200,400,600,1000]) 

# plt.subplot(2, 3, 6) 
# # ax.plot(T0, P0, linewidth=2.0,label = 'original')
# plt.plot(T_test, OLR8, '-c',linewidth=3.0,label = r'$T_{ideal}$ = 270 K' )
# plt.plot(T_test, OLR83, '-k',linewidth=2.0,label = r'$T_{ideal}$ = 250 K' )
# plt.plot(T_test, OLR84, '--k',linewidth=3.0,label = r'$T_{ideal}$ = 300 K' )
# # plt.plot(T_test, OLR62, '--k',linewidth=3.0,label = r'$T_{end}$ = 270 K')
# # ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
# plt.title(r"idealized OLR (changing $T_{ideal}$)")
# plt.xlabel("Temperature (K)")
# # plt.ylabel(r"$W/m^2$")
# # plt.gca().invert_yaxis()
# plt.legend(loc='upper left', fontsize='x-small')
# plt.ylim(150, 600)
# plt.xlim(200, 1000)
# plt.xticks([200,400,600,1000]) 


plt.show()

# %%
print(OLR5)
# print(T_test)
print(T_test[OLR5<301.327047])
print(T_test)
# Out:
# [220.         221.42380423 222.84760845 224.27141268 225.69521691
#  227.11902113 228.54282536 229.96662959 231.39043382 232.81423804
#  234.23804227 235.6618465  237.08565072 238.50945495 239.93325918
#  241.3570634  242.78086763 244.20467186 245.62847608 247.05228031
#  248.47608454 249.89988877 251.32369299 252.74749722 254.17130145
#  255.59510567 257.0189099  258.44271413 259.86651835 261.29032258
#  262.71412681 264.13793103 265.56173526 266.98553949 268.40934372
#  269.83314794]
# [ 220.          221.42380423  222.84760845  224.27141268  225.69521691
#   227.11902113  228.54282536  229.96662959  231.39043382  232.81423804
#   234.23804227  235.6618465   237.08565072  238.50945495  239.93325918
#   241.3570634   242.78086763  244.20467186  245.62847608  247.05228031
#   248.47608454  249.89988877  251.32369299  252.74749722  254.17130145
#   255.59510567  257.0189099   258.44271413  259.86651835  261.29032258
# ...

# %% [markdown]
# ## Now we start to compare nightside cloud radiative effect with Chaverot+2023

# %%
## read data
# read data from Chaverot+2023
coldtp = pd.read_csv('./screenshots/Chaverot2023_data/P1bar.csv',header=None)
# coldtp = pd.read_csv('./screenshots/Chaverot2023_data/P1bar.csv',header=None)
# assign headers
coldtp.columns = ["T", "F"]
# # make data in right order (necessary for interpolation)
# coldtp = coldtp.sort_values(by=['T'], ascending=True)
# interpolate data to a consistent pressure coordinate
T0 = coldtp['T']; F0 = coldtp['F'];
# P = np.logspace(2, 6, 100)
# cs = CubicSpline(P0, T0)
# T_TB2021 = cs(P)

coldtp = pd.read_csv('./screenshots/Chaverot2023_data/P1p5bar.csv',header=None)
# coldtp = pd.read_csv('./screenshots/Chaverot2023_data/P1bar.csv',header=None)
# assign headers
coldtp.columns = ["T", "F"]
# # make data in right order (necessary for interpolation)
# coldtp = coldtp.sort_values(by=['T'], ascending=True)
# interpolate data to a consistent pressure coordinate
T1 = coldtp['T']; F1 = coldtp['F'];

# plot
fig, ax = plt.subplots()

# ax.plot(T0, P0, linewidth=2.0,label = 'original')
# ax.plot(T_TB2021, P, linewidth = 2.0, label = 'interpolated')
ax.plot(T0, F0, linewidth = 2.0, label = r'$P_{vap} = 1 bar$')
ax.plot(T1, F1, linewidth = 2.0, label = r'$P_{vap} = 1.5 bar$')
# ax.plot(280,900,'r+',label='CC')

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.title("Chaverot2023 LW data")
plt.xlabel("Temperature (K)")
plt.ylabel("LW Forcing (W/m2)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (7,5)
ax.legend(loc='best', fontsize='x-small')
# ax.set_yscale('log')

plt.show()

# %%
def F_cloud(T):   # A function to include the nightside cloud effect
    if nightcloud =='yes':
        if T < 320:
            return 0
        elif T < 400:
            return (70 / 80) * (T - 320)  # Slope = 70 / (400-320)
        elif T < 700:
            return 70
        elif T < 800:
            return 70 + (40 / 100) * (T - 700)  # Slope = 40 / (800-700)
        else:
            return 110
    else:
        return 0

# %%
nightcloud = 'yes'
T_test = np.linspace(220, 1500, 900)
LW_cloud = []

for i in T_test:
    LW_test = F_cloud(i)
    LW_cloud.append(LW_test)

fig, ax = plt.subplots()

ax.plot(T_test, LW_cloud, '-k',linewidth=3.0,label = 'This work')
ax.plot(T0, F0, linewidth = 2.0, label = r'Chaverot+2023 ($P_{vap} = 1 bar$)')
ax.plot(T1, F1, linewidth = 2.0, label = r'Chaverot+2023 ($P_{vap} = 1.5 bar$)')
plt.title(r"Nightside cloud LW radiative effect")
plt.ylabel(r"$W/m^2$")

# ax.plot(T_test, a1_test, linewidth = 2.0, label = 'Yang2014')
# ax.plot(T_test, a2_test, linewidth = 2.0, label = 'Preesure effect')
# plt.title(r"$\epsilon$ vs T")
# plt.ylabel("Emission coefficient")

# print(a2_test/a1_test)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.xlabel("Temperature (K)")
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (10,6)
ax.legend(loc='best', fontsize='x-small')
# plt.xlim(250, 400)
# ax.set_yscale('log')
# plt.gca().invert_yaxis()

plt.show()
